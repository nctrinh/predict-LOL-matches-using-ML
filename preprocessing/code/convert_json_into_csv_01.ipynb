# %%
import json
import pandas as pd
import numpy as np

# %%
status_file_name = r'D:\Learning\ML\BTL\preprocessing\clean_data\status_per_min.json'

# %%
df = pd.read_json(status_file_name)

# %%
df = df.fillna(0)

# %%
df.to_csv(r"D:\Learning\ML\BTL\preprocessing\clean_data\status_per_min_01.csv", index=False)
